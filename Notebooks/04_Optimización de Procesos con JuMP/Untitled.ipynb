# %%
using Plots
pyplot()
#Plots.supported_markers()

plot(1:20:100,1:80:400, linestyle=:dashdot,lw=2.5, lc=RGB(0.6,0.4,0.8), marker=:utriangle,
    markeralpha=0.5,markercolor=RGB(0.9,0.,0.2), markerstrokewidth=2, markersize=15)
plot!(1:20:200,1:40:400)

#plot(1:4:100,1:8:200, style=:dot, lw=2, lc=:magenta, marker=(:hex,5,stroke(2,:blue)),foreground_color_legend=:blue,
#markeralpha=0.5)
# Out:
# <img src="data:image/png;base64,..." />
